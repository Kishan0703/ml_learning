# %%
import pickle
import pandas as pd

# %%
pipe= pickle.load(open('models/pipe.pkl','rb'))

# %%
test_input= {
    'Pclass':3,
    'Sex':'male',
    'Age':25,
    'SibSp':0,
    'Parch':0,
    'Fare':7.25,
    'Embarked':'S'
}

# %%
pipe.predict(pd.DataFrame([test_input]))
# Out:
# array([0])
