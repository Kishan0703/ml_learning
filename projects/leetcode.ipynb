# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The kernel failed to start as the Python Environment 'venv (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
data=pd.read_json('datasets/profiles.json')

# %%
data.head()
# Out:
#                                             username    rank  reputation  \
# 0  gAAAAABoFQH9IYBUcBmmQa-Mdjh31G4BbxDNYCJ2dkdSk3...  843893         0.0
# 1  gAAAAABoFQH9LPjKAdcERWPMTh4WLqdXCEYH-ej3zu3C6M...  168314         0.0
# 2  gAAAAABoFQH-eII_6bbuzJjZlvUhuMSBxt6zZXrgUx9pNP...  236942         3.0
# 3  gAAAAABoFQIB170-3DTr8TdP6GWBzL3GJGZYykS_Zn-SWY...  178755         0.0
# 4  gAAAAABoFQIPyPUmATgEbIz4ll53WrpXwH2w8hIvr4OWqV...  342143         0.0
#
#                                      languages  total_problems_solved  \
# 0                     {'C++': '79', 'C': '68'}                    147
# 1                  {'C++': '457', 'Java': '3'}                    460
# 2  {'C++': '383', 'Java': '1', 'Python3': '1'}                    385
# 3                               {'C++': '445'}                    445
# 4            {'C++': '303', 'JavaScript': '1'}                    304
#
#                                               skills  \
# ...
