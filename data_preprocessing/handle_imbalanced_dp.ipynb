# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
data=load_breast_cancer(as_frame=True)
df=data.frame

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data1=load_breast_cancer()
df1=pd.DataFrame(data1.data, columns=data1.feature_names)

# %%
df1
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# # example

# %%
from sklearn.datasets import fetch_openml

credit = fetch_openml("credit-g", version=1, as_frame=True)
df = credit.frame

print(df['class'].value_counts())
# Out:
# class
# good    700
# bad     300
# Name: count, dtype: int64

# %%
df
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0         6  critical/other existing credit
# 1          0<=X<200        48                   existing paid
# 2       no checking        12  critical/other existing credit
# 3                <0        42                   existing paid
# 4                <0        24              delayed previously
# ..              ...       ...                             ...
# 995     no checking        12                   existing paid
# 996              <0        30                   existing paid
# 997     no checking        12                   existing paid
# 998              <0        45                   existing paid
# 999        0<=X<200        45  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv           1169  no known savings         >=7
# 1               radio/tv           5951              <100      1<=X<4
# ...

# %%
good=df[df['class']=='good']
bad=df[df['class']=='bad']

# %%
print(good.shape, bad.shape)
# Out:
# (700, 21) (300, 21)

# %%
reduced_good=good.sample(300)
reduced_good.shape
# Out:
# (300, 21)

# %%
new_df=pd.concat([reduced_good,bad],axis=0)

# %%
new_df
# Out:
#     checking_status  duration                  credit_history  \
# 161     no checking        18  critical/other existing credit
# 283     no checking        15  critical/other existing credit
# 988              <0        24                   existing paid
# 818              <0        36                   existing paid
# 729           >=200        24  critical/other existing credit
# ..              ...       ...                             ...
# 979        0<=X<200        15                        all paid
# 980        0<=X<200        30  critical/other existing credit
# 981     no checking        48                   existing paid
# 983              <0        36                   existing paid
# 998              <0        45                   existing paid
#
#                  purpose  credit_amount    savings_status  employment  \
# 161              new car           1055              <100          <1
# 283  furniture/equipment           1520  no known savings         >=7
# ...
