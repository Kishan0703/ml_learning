# %%
import pandas as pd

# %%
import requests

url = "https://zillow56.p.rapidapi.com/search_polygon"

querystring = {"polygon":"34.03959576441558 -118.50636536779786,34.0418716916327 -118.50276047888184,34.042440663894304 -118.49846894445801,34.04201393505594 -118.49417741003418,34.04087598099002 -118.4897142142334,34.03945351693672 -118.48525101843262,34.03788877892429 -118.48095948400879,34.03618175908096 -118.47683961096192,34.034190192514366 -118.47271973791504,34.031629538228394 -118.46962983312989,34.02835747861639 -118.4677415579834,34.02465847668084 -118.46671158972168,34.02081703478521 -118.46636826696778,34.01697541902413 -118.46636826696778,34.01341821237762 -118.4673982352295,34.011283816847104 -118.47100312414551,34.01057233974687 -118.47563798132325,34.01043004361143 -118.47992951574707,34.01071463564384 -118.48439271154786,34.01156840601794 -118.48868424597168,34.01270675316253 -118.49297578039551,34.01398737545716 -118.49709565344239,34.01555255425154 -118.50104386511231,34.01754455825562 -118.50464875402832,34.02039019717532 -118.50756699743653,34.02352028980117 -118.50962693395996,34.02707707311613 -118.51065690222168,34.03063370735633 -118.50997025671387,34.034190192514366 -118.5091119498291,34.03774652858273 -118.50825364294434,34.03959576441558 -118.50636536779786","output":"json","status":"forSale","sortSelection":"priorityscore","listing_type":"by_agent","doz":"any"}

headers = {
	"x-rapidapi-key": "333241ee78mshb1f03dfddfa879cp12d4f0jsn16a3cc6e99ae",
	"x-rapidapi-host": "zillow56.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'bathrooms': 2.0, 'bedrooms': 2.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'CONDO', 'imgSrc': 'https://photos.zillowstatic.com/fp/9ac0d58bd947990e98a7c6feddc32060-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.025856, 'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True}, 'livingArea': 1004.0, 'longitude': -118.501976, 'lotAreaUnit': 'sqft', 'lotAreaValue': 7483.608, 'openHouse': 'Sat. 2-4pm', 'open_house_info': {'open_house_showing': [{'open_house_end': 1760223600000, 'open_house_start': 1760216400000}, {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]}, 'price': 1165000.0, 'priceForHDP': 1165000.0, 'rentZestimate': 4490, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '817 6th St APT A', 'taxAssessedValue': 964245.0, 'timeOnZillow': 115211000, 'unit': 'Apt A', 'zestimate': 1157100, 'zipcode': '90403', 'zpid': 20484992}, {'bathrooms': 4.0, 'bedrooms': 3.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'datePriceChanged': 1759215600000, 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'MULTI_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/c6843720f4bebc52801ff6fdece15ed9-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.034615, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 1469.0, 'longitude': -118.48012, 'lotAreaUnit': 'sqft', 'lotAreaValue': 6211.656, 'price': 1199000.0, 'priceChange': -150000, 'priceForHDP': 1199000.0, 'priceReduction': '$150,000 (Sep 30)', 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '1147 24th St #A-B', 'timeOnZillow': 6332639000, 'unit': '# A-B', 'zestimate': 1234900, 'zipcode': '90403', 'zpid': 455351929}, {'bathrooms': 3.0, 'bedrooms': 2.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'CONDO', 'imgSrc': 'https://photos.zillowstatic.com/fp/cfc9a51e88f475eb8339bcdcb49dab43-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.017593, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 1418.0, 'longitude': -118.48273, 'lotAreaUnit': 'sqft', 'lotAreaValue': 7514.0, 'price': 990000.0, 'priceForHDP': 990000.0, 'rentZestimate': 4918, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '1754 11th St UNIT 101', 'taxAssessedValue': 391903.0, 'timeOnZillow': 284210000, 'unit': 'Unit 101', 'zestimate': 1005000, 'zipcode': '90404', 'zpid': 20479916}, {'bathrooms': 15.0, 'bedrooms': 11.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/fa16ff881b0352aa744bad0da9c936fb-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.0192, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 9899.0, 'longitude': -118.505844, 'lotAreaUnit': 'sqft', 'lotAreaValue': 5505.984, 'price': 38500000.0, 'priceForHDP': 38500000.0, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '938-940 Palisades Beach Rd', 'timeOnZillow': 1001423000, 'zipcode': '90403', 'zpid': 456957893}, {'bathrooms': 1.0, 'bedrooms': 1.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'datePriceChanged': 17553 ...

# %%
data=response.json()

# %%
data
# Out:
# {'results': [{'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9ac0d58bd947990e98a7c6feddc32060-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.025856,
#    'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#    'livingArea': 1004.0,
#    'longitude': -118.501976,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7483.608,
#    'openHouse': 'Sat. 2-4pm',
#    'open_house_info': {'open_house_showing': [{'open_house_end': 1760223600000,
#       'open_house_start': 1760216400000},
#      {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]},
#    'price': 1165000.0,
#    'priceForHDP': 1165000.0,
#    'rentZestimate': 4490,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '817 6th St APT A',
#    'taxAssessedValue': 964245.0,
#    'timeOnZillow': 115211000,
#    'unit': 'Apt A',
#    'zestimate': 1157100,
#    'zipcode': '90403',
#    'zpid': 20484992},
#   {'bathrooms': 4.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1759215600000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'MULTI_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c6843720f4bebc52801ff6fdece15ed9-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.034615,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1469.0,
#    'longitude': -118.48012,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 6211.656,
#    'price': 1199000.0,
#    'priceChange': -150000,
#    'priceForHDP': 1199000.0,
#    'priceReduction': '$150,000 (Sep 30)',
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1147 24th St #A-B',
#    'timeOnZillow': 6332639000,
#    'unit': '# A-B',
#    'zestimate': 1234900,
#    'zipcode': '90403',
#    'zpid': 455351929},
#   {'bathrooms': 3.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cfc9a51e88f475eb8339bcdcb49dab43-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.017593,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1418.0,
#    'longitude': -118.48273,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7514.0,
#    'price': 990000.0,
#    'priceForHDP': 990000.0,
#    'rentZestimate': 4918,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1754 11th St UNIT 101',
#    'taxAssessedValue': 391903.0,
#    'timeOnZillow': 284210000,
#    'unit': 'Unit 101',
#    'zestimate': 1005000,
#    'zipcode': '90404',
#    'zpid': 20479916},
#   {'bathrooms': 15.0,
#    'bedrooms': 11.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fa16ff881b0352aa744bad0da9c936fb-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.0192,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 9899.0,
#    'longitude': -118.505844,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 5505.984,
#    'price': 38500000.0,
#    'priceForHDP': 38500000.0,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '938-940 Palisades Beach Rd',
#    'timeOnZillow': 1001423000,
#    'zipcode': '90403',
#    'zpid': 456957893},
#   {'bathrooms': 1.0,
#    'bedrooms': 1.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1755327600000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0ab3516293ce9fa2c72e5acecfb6a505-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02828,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 440.0,
#    'longitude': -118.49284,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 1319.868,
#    'price': 999000.0,
#    'priceChange': -101000,
#    'priceForHDP': 999000.0,
#    'priceReduction': '$101,000 (Aug 16)',
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1012 1/2 Euclid St',
#    'taxAssessedValue': 913190.0,
#    'timeOnZillow': 17922338000,
#    'zipcode': '90403',
#    'zpid': 20478685},
#   {'bathrooms': 1.0,
#    'bedrooms': 1.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1756364400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/379ba2c7ab01cefcfd37b14e2bc5cde8-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.020752,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1043.0,
#    'longitude': -118.50077,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.6892791551882461,
#    'price': 599100.0,
#    'priceChange': -40800,
#    'priceForHDP': 599100.0,
#    'priceReduction': '$40,800 (Aug 28)',
#    'rentZestimate': 4503,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1040 4th St #112',
#    'taxAssessedValue': 634173.0,
#    'timeOnZillow': 131439410000,
#    'unit': '# 112',
#    'zipcode': '90403',
#    'zpid': 20485330},
#   {'bathrooms': 6.0,
#    'bedrooms': 4.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3cbebb772f87fa1e60b32a4072e6f2e4-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.01903,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 5030.0,
#    'longitude': -118.50577,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 5536.476,
#    'price': 19500000.0,
#    'priceForHDP': 19500000.0,
#    'rentZestimate': 5702,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '940 Palisades Beach Rd',
#    'taxAssessedValue': 3959878.0,
#    'timeOnZillow': 1001423000,
#    'zestimate': 18681200,
#    'zipcode': '90403',
#    'zpid': 20485846},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1756882800000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ca026d0c07e1a36cfd5bf28f6dc994ba-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02569,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 918.0,
#    'longitude': -118.501,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7483.608,
#    'price': 899000.0,
#    'priceChange': -30000,
#    'priceForHDP': 899000.0,
#    'priceReduction': '$30,000 (Sep 3)',
#    'rentZestimate': 4221,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '844 7th St APT 1',
#    'taxAssessedValue': 393971.0,
#    'timeOnZillow': 9899414000,
#    'unit': 'Apt 1',
#    'zestimate': 903700,
#    'zipcode': '90403',
#    'zpid': 20484960},
#   {'bathrooms': 1.0,
#    'bedrooms': 1.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1750316400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/08b9533ab23c1b4c70048324e8396623-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02662,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 722.0,
#    'longitude': -118.47892,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.3446,
#    'price': 499000.0,
#    'priceChange': -51000,
#    'priceForHDP': 499000.0,
#    'priceReduction': '',
#    'rentZestimate': 2931,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1912 Broadway APT 107',
#    'taxAssessedValue': 396594.0,
#    'timeOnZillow': 12120882000,
#    'unit': 'Apt 107',
#    'zipcode': '90404',
#    'zpid': 92426247},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3b06e5e0488deefa29c54c646138d377-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02153,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1355.0,
#    'longitude': -118.5035,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.3446,
#    'price': 1149000.0,
#    'priceForHDP': 1149000.0,
#    'rentZestimate': 5402,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '930 3rd St APT 307',
#    'taxAssessedValue': 1250469.0,
#    'timeOnZillow': 6080657000,
#    'unit': 'Apt 307',
#    'zestimate': 1150800,
#    'zipcode': '90403',
#    'zpid': 20485470},
#   {'bathrooms': 6.0,
#    'bedrooms': 6.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1750230000000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8221c459d7209f84c2873d0bc6c1210a-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.03766,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 5900.0,
#    'longitude': -118.50507,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.2881,
#    'price': 8995000.0,
#    'priceChange': -454000,
#    'priceForHDP': 8995000.0,
#    'priceReduction': '',
#    'rentZestimate': 28257,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1202 San Vicente Blvd',
#    'taxAssessedValue': 4584595.0,
#    'timeOnZillow': 13354751000,
#    'zipcode': '90402',
#    'zpid': 20477450},
#   {'bathrooms': 3.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6568e5c8d02ed024670101238ed99590-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.024708,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1865.0,
#    'longitude': -118.51018,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 1.5479,
#    'price': 2649000.0,
#    'priceForHDP': 2649000.0,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '515 Ocean Ave UNIT 502N',
#    'timeOnZillow': 2445326000,
#    'unit': 'Unit 502N',
#    'zipcode': '90402',
#    'zpid': 456559605},
#   {'bathrooms': 4.0,
#    'bedrooms': 6.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1758870000000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/990c03a3a764ff219370730760d0802b-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.03985,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 3103.0,
#    'longitude': -118.50098,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7527.168,
#    'price': 3995000.0,
#    'priceChange': 45000,
#    'priceForHDP': 3995000.0,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '212 16th St',
#    'taxAssessedValue': 286706.0,
#    'timeOnZillow': 4529628000,
#    'zipcode': '90402',
#    'zpid': 20477160},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1757055600000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/77e1c5f102c9809df8452a3552bb6117-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.025658,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 2000.0,
#    'longitude': -118.50825,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 10624.284,
#    'price': 5395000.0,
#    'priceChange': -100000,
#    'priceForHDP': 5395000.0,
#    'priceReduction': '$100,000 (Sep 5)',
#    'rentZestimate': 4919,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '227 Alta Ave',
#    'taxAssessedValue': 3163774.0,
#    'timeOnZillow': 2718797000,
#    'zestimate': 5296100,
#    'zipcode': '90402',
#    'zpid': 20486265},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1756364400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/521d94e157f6515eafa98cde3d7329a4-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.033016,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1803.0,
#    'longitude': -118.47912,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 5318.676,
#    'price': 1360000.0,
#    'priceChange': -30000,
#    'priceForHDP': 1360000.0,
#    'priceReduction': '$30,000 (Aug 28)',
#    'rentZestimate': 6633,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1240 24th St UNIT 3',
#    'taxAssessedValue': 1456414.0,
#    'timeOnZillow': 6951843000,
#    'unit': 'Unit 3',
#    'zestimate': 1354400,
#    'zipcode': '90404',
#    'zpid': 20474535},
#   {'bathrooms': 3.0,
#    'bedrooms': 6.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7dedc9fefc17595800163e0a1cafdafb-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.016705,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 2751.0,
#    'longitude': -118.47945,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7497.0,
#    'price': 1950000.0,
#    'priceForHDP': 1950000.0,
#    'rentZestimate': 5535,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1836 Euclid St',
#    'taxAssessedValue': 1250567.0,
#    'timeOnZillow': 716210000,
#    'zestimate': 1930900,
#    'zipcode': '90404',
#    'zpid': 20480089},
#   {'bathrooms': 4.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5e1918eb31e27195c58ccfd65c4db5b5-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.030945,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1850.0,
#    'longitude': -118.4895,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7505.388,
#    'price': 1795000.0,
#    'priceForHDP': 1795000.0,
#    'rentZestimate': 7588,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1013 16th St UNIT 101',
#    'taxAssessedValue': 1210486.0,
#    'timeOnZillow': 6503423000,
#    'unit': 'Unit 101',
#    'zestimate': 1780000,
#    'zipcode': '90403',
#    'zpid': 20478100},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1759474800000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/511e1956dde315869615a5a7301828db-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.033455,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 2142.0,
#    'longitude': -118.49165,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7505.388,
#    'price': 2595000.0,
#    'priceChange': -100000,
#    'priceForHDP': 2595000.0,
#    'priceReduction': '$100,000 (Oct 3)',
#    'rentZestimate': 8328,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '838 17th St APT 105',
#    'taxAssessedValue': 2236860.0,
#    'timeOnZillow': 975846000,
#    'unit': 'Apt 105',
#    'zestimate': 2549100,
#    'zipcode': '90403',
#    'zpid': 51582400},
#   {'bathrooms': 4.0,
#    'bedrooms': 5.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7350ec6dd16ce7ccea394a0c38ff3ec0-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.039165,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 3250.0,
#    'longitude': -118.50202,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7496.676,
#    'price': 5195000.0,
#    'priceForHDP': 5195000.0,
#    'rentZestimate': 17855,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '210 15th St',
#    'taxAssessedValue': 3865800.0,
#    'timeOnZillow': 970158000,
#    'zestimate': 5193300,
#    'zipcode': '90402',
#    'zpid': 20477206},
#   {'bathrooms': 4.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1b7dd78269c362b18695c71a49b83701-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.027794,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 2580.0,
#    'longitude': -118.49793,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7527.168,
#    'price': 2395000.0,
#    'priceForHDP': 2395000.0,
#    'rentZestimate': 7674,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '852 10th St APT 1',
#    'taxAssessedValue': 2043593.0,
#    'timeOnZillow': 307458000,
#    'unit': 'Apt 1',
#    'zestimate': 2377600,
#    'zipcode': '90403',
#    'zpid': 102961436},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3f69cc5669d280665b44daac091b0ff4-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.032608,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1588.0,
#    'longitude': -118.48961,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.34450000000000003,
#    'price': 1625000.0,
#    'priceForHDP': 1625000.0,
#    'rentZestimate': 6779,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '933 17th St UNIT 14',
#    'taxAssessedValue': 1485834.0,
#    'timeOnZillow': 5299736000,
#    'unit': 'Unit 14',
#    'zestimate': 1607500,
#    'zipcode': '90403',
#    'zpid': 20475069},
#   {'bathrooms': 8.0,
#    'bedrooms': 6.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f063974b84bbecb5541a4f073f0a6a9b-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.028465,
#    'listing_sub_type': {'is_newHome': True},
#    'livingArea': 7710.0,
#    'longitude': -118.50596,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.25358126721763086,
#    'newConstructionType': 'BUILDER_SPEC',
#    'price': 17818000.0,
#    'priceForHDP': 17818000.0,
#    'rentZestimate': 6712,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '528 Marguerita Ave',
#    'taxAssessedValue': 5618160.0,
#    'timeOnZillow': 1321010000,
#    'zestimate': 17165100,
#    'zipcode': '90402',
#    'zpid': 20486488},
#   {'bathrooms': 6.0,
#    'bedrooms': 5.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c914d925d44dd0e3630d4f9ed9719743-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.040005,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 4374.0,
#    'longitude': -118.48921,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7562.016,
#    'price': 6949000.0,
#    'priceForHDP': 6949000.0,
#    'rentZestimate': 22694,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '624 22nd St',
#    'taxAssessedValue': 4852502.0,
#    'timeOnZillow': 655165000,
#    'zipcode': '90402',
#    'zpid': 20476240},
#   {'bathrooms': 4.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1758524400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/297c6fe4158d91adab3e8fa438c2bec9-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.0276,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 4695.0,
#    'longitude': -118.50919,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 9801.0,
#    'price': 7475000.0,
#    'priceChange': -224000,
#    'priceForHDP': 7475000.0,
#    'priceReduction': '$224,000 (Sep 22)',
#    'rentZestimate': 7847,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '416 4th St',
#    'taxAssessedValue': 3684844.0,
#    'timeOnZillow': 7643044000,
#    'zestimate': 7482300,
#    'zipcode': '90402',
#    'zpid': 20486251},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/26787ea10e376ad86509d6999a1478cb-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.033756,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 935.0,
#    'longitude': -118.488304,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7984.548,
#    'price': 799000.0,
#    'priceForHDP': 799000.0,
#    'rentZestimate': 4278,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '934 19th St UNIT 5',
#    'taxAssessedValue': 382400.0,
#    'timeOnZillow': 1245610000,
#    'unit': 'Unit 5',
#    'zestimate': 800300,
#    'zipcode': '90403',
#    'zpid': 20475159},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/85b39c939bd56a98535421c5cce194c6-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02964,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1213.0,
#    'longitude': -118.49457,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.5171,
#    'price': 1425000.0,
#    'priceForHDP': 1425000.0,
#    'rentZestimate': 5194,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '900 Euclid St APT 404',
#    'taxAssessedValue': 1259184.0,
#    'timeOnZillow': 285514000,
#    'unit': 'Apt 404',
#    'zestimate': 1411600,
#    'zipcode': '90403',
#    'zpid': 20478617},
#   {'bathrooms': 7.0,
#    'bedrooms': 6.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f962f4612e338707fa65b3e24268de82-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.034992,
#    'listing_sub_type': {'is_newHome': True},
#    'livingArea': 5018.0,
#    'longitude': -118.49976,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7501.032,
#    'newConstructionType': 'BUILDER_SPEC',
#    'price': 7995000.0,
#    'priceForHDP': 7995000.0,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '443 Euclid St',
#    'taxAssessedValue': 3431044.0,
#    'timeOnZillow': 10714229000,
#    'zipcode': '90402',
#    'zpid': 20477746},
#   {'bathrooms': 3.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2bb2e280c1f34f50db3aa3999fed4b9d-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.031902,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1356.0,
#    'longitude': -118.47384,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7008.804,
#    'price': 1225000.0,
#    'priceForHDP': 1225000.0,
#    'rentZestimate': 5093,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1443 25th St APT 2',
#    'taxAssessedValue': 873000.0,
#    'timeOnZillow': 384908000,
#    'unit': 'Apt 2',
#    'zestimate': 1205500,
#    'zipcode': '90404',
#    'zpid': 20473885},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/adf94cc6b6dcbd2d8b8c9ce00f9a8e3a-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.01113,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 842.0,
#    'longitude': -118.4833,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.46759999999999996,
#    'price': 949000.0,
#    'priceForHDP': 949000.0,
#    'rentZestimate': 3884,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '643 Bay St',
#    'taxAssessedValue': 880801.0,
#    'timeOnZillow': 1773329000,
#    'zestimate': 956900,
#    'zipcode': '90405',
#    'zpid': 20484049},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5ddc945798f128072debd34fc913c26e-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.033894,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1228.0,
#    'longitude': -118.47613,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 1.7036,
#    'price': 1089000.0,
#    'priceForHDP': 1089000.0,
#    'rentZestimate': 5216,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '2508 Arizona Ave APT 3',
#    'taxAssessedValue': 376687.0,
#    'timeOnZillow': 1245015000,
#    'unit': 'Apt 3',
#    'zestimate': 1079700,
#    'zipcode': '90404',
#    'zpid': 20474614},
#   {'bathrooms': 38.0,
#    'bedrooms': 38.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1756796400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'MULTI_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f84ebebd6a1780799e12591ef535466f-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02093,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 30954.0,
#    'longitude': -118.50543,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.34460514233241507,
#    'price': 30622000.0,
#    'priceChange': -2000000,
#    'priceForHDP': 30622000.0,
#    'priceReduction': '$2,000,000 (Sep 2)',
#    'rentZestimate': 3027,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '901 Ocean Ave',
#    'timeOnZillow': 7973810000,
#    'zipcode': '90403',
#    'zpid': 2068792684},
#   {'bathrooms': 4.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/799da9e2c3ff8411dac74555bb0615f0-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.031742,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 2085.0,
#    'longitude': -118.494125,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.3446,
#    'price': 2699000.0,
#    'priceForHDP': 2699000.0,
#    'rentZestimate': 8255,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '831 14th St APT 2',
#    'taxAssessedValue': 2028780.0,
#    'timeOnZillow': 2788432000,
#    'unit': 'Apt 2',
#    'zestimate': 2650700,
#    'zipcode': '90403',
#    'zpid': 20478314},
#   {'bathrooms': 8.0,
#    'bedrooms': 7.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bf15b12e5f0d5da1ed06d7da7fcdfe46-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.041023,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 8400.0,
#    'longitude': -118.49285,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 8938.512,
#    'price': 19995000.0,
#    'priceForHDP': 19995000.0,
#    'rentZestimate': 17770,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '439 21st St',
#    'taxAssessedValue': 4284000.0,
#    'timeOnZillow': 11870599000,
#    'zestimate': 19287800,
#    'zipcode': '90402',
#    'zpid': 20476410},
#   {'bathrooms': 2.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/dd91f2355f4064ce8464d0eab79461e2-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.03284,
#    'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#    'livingArea': 1920.0,
#    'longitude': -118.49551,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7527.168,
#    'openHouse': 'Tue. 11am-2pm',
#    'open_house_info': {'open_house_showing': [{'open_house_end': 1759870800000,
#       'open_house_start': 1759860000000},
#      {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]},
#    'price': 3999000.0,
#    'priceForHDP': 3999000.0,
#    'rentZestimate': 5446,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '723 14th St',
#    'taxAssessedValue': 1456021.0,
#    'timeOnZillow': 2809863000,
#    'zestimate': 2932100,
#    'zipcode': '90402',
#    'zpid': 20477297},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1759129200000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2a09adcdd68b48879861bf8c263f5b20-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.03607,
#    'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#    'livingArea': 1019.0,
#    'longitude': -118.48751,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 2988.216,
#    'openHouse': '10/16 10am-12pm',
#    'open_house_info': {'open_house_showing': [{'open_house_end': 1760641200000,
#       'open_house_start': 1760634000000}]},
#    'price': 2149999.0,
#    'priceChange': -50000,
#    'priceForHDP': 2149999.0,
#    'priceReduction': '$50,000 (Sep 29)',
#    'rentZestimate': 6534,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '2021 Idaho Ave',
#    'taxAssessedValue': 1893527.0,
#    'timeOnZillow': 2982424000,
#    'zestimate': 2130400,
#    'zipcode': '90403',
#    'zpid': 20474861},
#   {'bathrooms': 3.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a32dadfc7b19df28b1c2b23cf4c7a23d-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02341,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1601.0,
#    'longitude': -118.50571,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7487.964,
#    'price': 1585000.0,
#    'priceForHDP': 1585000.0,
#    'rentZestimate': 7589,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '802 3rd St APT B',
#    'taxAssessedValue': 476496.0,
#    'timeOnZillow': 984628000,
#    'unit': 'Apt B',
#    'zestimate': 1582000,
#    'zipcode': '90403',
#    'zpid': 20485537},
#   {'bathrooms': 2.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1757401200000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9c6fbb26017d30d4c9464ca66fe1c12f-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.034058,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1240.0,
#    'longitude': -118.48344,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 6351.048,
#    'price': 2650000.0,
#    'priceChange': -40000,
#    'priceForHDP': 2650000.0,
#    'priceReduction': '$40,000 (Sep 9)',
#    'rentZestimate': 7391,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1060 22nd St',
#    'taxAssessedValue': 756793.0,
#    'timeOnZillow': 6359397000,
#    'zestimate': 2623200,
#    'zipcode': '90403',
#    'zpid': 20475571},
#   {'bathrooms': 1.0,
#    'bedrooms': 2.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/96c92b05844a2faecb70765946f55d28-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.01245,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 785.0,
#    'longitude': -118.48446,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7501.032,
#    'price': 795000.0,
#    'priceForHDP': 795000.0,
#    'rentZestimate': 3410,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1835 7th St APT D',
#    'taxAssessedValue': 842723.0,
#    'timeOnZillow': 1075774000,
#    'unit': 'Apt D',
#    'zestimate': 791300,
#    'zipcode': '90401',
#    'zpid': 20484693},
#   {'bathrooms': 5.0,
#    'bedrooms': 4.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1752908400000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'SINGLE_FAMILY',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bc7b9cf2f39ee122c91d24b99f95538b-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.033585,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 5228.0,
#    'longitude': -118.50931,
#    'lotAreaUnit': 'acres',
#    'lotAreaValue': 0.3438,
#    'price': 6750000.0,
#    'priceChange': -449000,
#    'priceForHDP': 6750000.0,
#    'priceReduction': '$449,000 (Jul 19)',
#    'rentZestimate': 6125,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '562 Stassi Ln',
#    'taxAssessedValue': 4987677.0,
#    'timeOnZillow': 18268525000,
#    'zestimate': 6939000,
#    'zipcode': '90402',
#    'zpid': 20539643},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'datePriceChanged': 1759474800000,
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'TOWNHOUSE',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0e18d02c859abd1efb70a92a16cdada3-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.02262,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1963.0,
#    'longitude': -118.50478,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7501.032,
#    'price': 2699000.0,
#    'priceChange': -151000,
#    'priceForHDP': 2699000.0,
#    'priceReduction': '$151,000 (Oct 3)',
#    'rentZestimate': 7539,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '844 3rd St #5',
#    'taxAssessedValue': 2192756.0,
#    'timeOnZillow': 3120865000,
#    'unit': '# 5',
#    'zestimate': 2649300,
#    'zipcode': '90403',
#    'zpid': 55198014},
#   {'bathrooms': 3.0,
#    'bedrooms': 3.0,
#    'city': 'Santa Monica',
#    'country': 'USA',
#    'currency': 'USD',
#    'daysOnZillow': -1,
#    'homeStatus': 'FOR_SALE',
#    'homeStatusForHDP': 'FOR_SALE',
#    'homeType': 'CONDO',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/69c1e7b08aaee035f696eb112dfdb1f6-p_e.jpg',
#    'isFeatured': False,
#    'isNonOwnerOccupied': True,
#    'isPreforeclosureAuction': False,
#    'isPremierBuilder': False,
#    'isShowcaseListing': False,
#    'isUnmappable': False,
#    'isZillowOwned': False,
#    'latitude': 34.01978,
#    'listing_sub_type': {'is_FSBA': True},
#    'livingArea': 1850.0,
#    'longitude': -118.50334,
#    'lotAreaUnit': 'sqft',
#    'lotAreaValue': 7514.1,
#    'price': 2694000.0,
#    'priceForHDP': 2694000.0,
#    'rentZestimate': 7813,
#    'shouldHighlight': False,
#    'state': 'CA',
#    'streetAddress': '1012 2nd St APT 1',
#    'timeOnZillow': 2789005000,
#    'unit': 'Apt 1',
#    'zestimate': 2678600,
#    'zipcode': '90403',
#    'zpid': 2098895547}],
#  'resultsPerPage': 41,
#  'totalPages': 4,
#  'totalResultCount': 152}

# %%
data.keys()
# Out:
# dict_keys(['results', 'resultsPerPage', 'totalPages', 'totalResultCount'])

# %%
data.values()
# Out:
# dict_values([[{'bathrooms': 2.0, 'bedrooms': 2.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'CONDO', 'imgSrc': 'https://photos.zillowstatic.com/fp/9ac0d58bd947990e98a7c6feddc32060-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.025856, 'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True}, 'livingArea': 1004.0, 'longitude': -118.501976, 'lotAreaUnit': 'sqft', 'lotAreaValue': 7483.608, 'openHouse': 'Sat. 2-4pm', 'open_house_info': {'open_house_showing': [{'open_house_end': 1760223600000, 'open_house_start': 1760216400000}, {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]}, 'price': 1165000.0, 'priceForHDP': 1165000.0, 'rentZestimate': 4490, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '817 6th St APT A', 'taxAssessedValue': 964245.0, 'timeOnZillow': 115211000, 'unit': 'Apt A', 'zestimate': 1157100, 'zipcode': '90403', 'zpid': 20484992}, {'bathrooms': 4.0, 'bedrooms': 3.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'datePriceChanged': 1759215600000, 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'MULTI_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/c6843720f4bebc52801ff6fdece15ed9-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.034615, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 1469.0, 'longitude': -118.48012, 'lotAreaUnit': 'sqft', 'lotAreaValue': 6211.656, 'price': 1199000.0, 'priceChange': -150000, 'priceForHDP': 1199000.0, 'priceReduction': '$150,000 (Sep 30)', 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '1147 24th St #A-B', 'timeOnZillow': 6332639000, 'unit': '# A-B', 'zestimate': 1234900, 'zipcode': '90403', 'zpid': 455351929}, {'bathrooms': 3.0, 'bedrooms': 2.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'CONDO', 'imgSrc': 'https://photos.zillowstatic.com/fp/cfc9a51e88f475eb8339bcdcb49dab43-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.017593, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 1418.0, 'longitude': -118.48273, 'lotAreaUnit': 'sqft', 'lotAreaValue': 7514.0, 'price': 990000.0, 'priceForHDP': 990000.0, 'rentZestimate': 4918, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '1754 11th St UNIT 101', 'taxAssessedValue': 391903.0, 'timeOnZillow': 284210000, 'unit': 'Unit 101', 'zestimate': 1005000, 'zipcode': '90404', 'zpid': 20479916}, {'bathrooms': 15.0, 'bedrooms': 11.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/fa16ff881b0352aa744bad0da9c936fb-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 34.0192, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 9899.0, 'longitude': -118.505844, 'lotAreaUnit': 'sqft', 'lotAreaValue': 5505.984, 'price': 38500000.0, 'priceForHDP': 38500000.0, 'shouldHighlight': False, 'state': 'CA', 'streetAddress': '938-940 Palisades Beach Rd', 'timeOnZillow': 1001423000, 'zipcode': '90403', 'zpid': 456957893}, {'bathrooms': 1.0, 'bedrooms': 1.0, 'city': 'Santa Monica', 'country': 'USA', 'currency': 'USD', 'datePriceChanged': 1755 ...

# %%
data['results']
# Out:
# [{'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/9ac0d58bd947990e98a7c6feddc32060-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.025856,
#   'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#   'livingArea': 1004.0,
#   'longitude': -118.501976,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7483.608,
#   'openHouse': 'Sat. 2-4pm',
#   'open_house_info': {'open_house_showing': [{'open_house_end': 1760223600000,
#      'open_house_start': 1760216400000},
#     {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]},
#   'price': 1165000.0,
#   'priceForHDP': 1165000.0,
#   'rentZestimate': 4490,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '817 6th St APT A',
#   'taxAssessedValue': 964245.0,
#   'timeOnZillow': 115211000,
#   'unit': 'Apt A',
#   'zestimate': 1157100,
#   'zipcode': '90403',
#   'zpid': 20484992},
#  {'bathrooms': 4.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1759215600000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'MULTI_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c6843720f4bebc52801ff6fdece15ed9-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.034615,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1469.0,
#   'longitude': -118.48012,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 6211.656,
#   'price': 1199000.0,
#   'priceChange': -150000,
#   'priceForHDP': 1199000.0,
#   'priceReduction': '$150,000 (Sep 30)',
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1147 24th St #A-B',
#   'timeOnZillow': 6332639000,
#   'unit': '# A-B',
#   'zestimate': 1234900,
#   'zipcode': '90403',
#   'zpid': 455351929},
#  {'bathrooms': 3.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/cfc9a51e88f475eb8339bcdcb49dab43-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.017593,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1418.0,
#   'longitude': -118.48273,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7514.0,
#   'price': 990000.0,
#   'priceForHDP': 990000.0,
#   'rentZestimate': 4918,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1754 11th St UNIT 101',
#   'taxAssessedValue': 391903.0,
#   'timeOnZillow': 284210000,
#   'unit': 'Unit 101',
#   'zestimate': 1005000,
#   'zipcode': '90404',
#   'zpid': 20479916},
#  {'bathrooms': 15.0,
#   'bedrooms': 11.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/fa16ff881b0352aa744bad0da9c936fb-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.0192,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 9899.0,
#   'longitude': -118.505844,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 5505.984,
#   'price': 38500000.0,
#   'priceForHDP': 38500000.0,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '938-940 Palisades Beach Rd',
#   'timeOnZillow': 1001423000,
#   'zipcode': '90403',
#   'zpid': 456957893},
#  {'bathrooms': 1.0,
#   'bedrooms': 1.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1755327600000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/0ab3516293ce9fa2c72e5acecfb6a505-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02828,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 440.0,
#   'longitude': -118.49284,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 1319.868,
#   'price': 999000.0,
#   'priceChange': -101000,
#   'priceForHDP': 999000.0,
#   'priceReduction': '$101,000 (Aug 16)',
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1012 1/2 Euclid St',
#   'taxAssessedValue': 913190.0,
#   'timeOnZillow': 17922338000,
#   'zipcode': '90403',
#   'zpid': 20478685},
#  {'bathrooms': 1.0,
#   'bedrooms': 1.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1756364400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/379ba2c7ab01cefcfd37b14e2bc5cde8-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.020752,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1043.0,
#   'longitude': -118.50077,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.6892791551882461,
#   'price': 599100.0,
#   'priceChange': -40800,
#   'priceForHDP': 599100.0,
#   'priceReduction': '$40,800 (Aug 28)',
#   'rentZestimate': 4503,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1040 4th St #112',
#   'taxAssessedValue': 634173.0,
#   'timeOnZillow': 131439410000,
#   'unit': '# 112',
#   'zipcode': '90403',
#   'zpid': 20485330},
#  {'bathrooms': 6.0,
#   'bedrooms': 4.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3cbebb772f87fa1e60b32a4072e6f2e4-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.01903,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 5030.0,
#   'longitude': -118.50577,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 5536.476,
#   'price': 19500000.0,
#   'priceForHDP': 19500000.0,
#   'rentZestimate': 5702,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '940 Palisades Beach Rd',
#   'taxAssessedValue': 3959878.0,
#   'timeOnZillow': 1001423000,
#   'zestimate': 18681200,
#   'zipcode': '90403',
#   'zpid': 20485846},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1756882800000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/ca026d0c07e1a36cfd5bf28f6dc994ba-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02569,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 918.0,
#   'longitude': -118.501,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7483.608,
#   'price': 899000.0,
#   'priceChange': -30000,
#   'priceForHDP': 899000.0,
#   'priceReduction': '$30,000 (Sep 3)',
#   'rentZestimate': 4221,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '844 7th St APT 1',
#   'taxAssessedValue': 393971.0,
#   'timeOnZillow': 9899414000,
#   'unit': 'Apt 1',
#   'zestimate': 903700,
#   'zipcode': '90403',
#   'zpid': 20484960},
#  {'bathrooms': 1.0,
#   'bedrooms': 1.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1750316400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/08b9533ab23c1b4c70048324e8396623-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02662,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 722.0,
#   'longitude': -118.47892,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.3446,
#   'price': 499000.0,
#   'priceChange': -51000,
#   'priceForHDP': 499000.0,
#   'priceReduction': '',
#   'rentZestimate': 2931,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1912 Broadway APT 107',
#   'taxAssessedValue': 396594.0,
#   'timeOnZillow': 12120882000,
#   'unit': 'Apt 107',
#   'zipcode': '90404',
#   'zpid': 92426247},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3b06e5e0488deefa29c54c646138d377-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02153,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1355.0,
#   'longitude': -118.5035,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.3446,
#   'price': 1149000.0,
#   'priceForHDP': 1149000.0,
#   'rentZestimate': 5402,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '930 3rd St APT 307',
#   'taxAssessedValue': 1250469.0,
#   'timeOnZillow': 6080657000,
#   'unit': 'Apt 307',
#   'zestimate': 1150800,
#   'zipcode': '90403',
#   'zpid': 20485470},
#  {'bathrooms': 6.0,
#   'bedrooms': 6.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1750230000000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/8221c459d7209f84c2873d0bc6c1210a-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.03766,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 5900.0,
#   'longitude': -118.50507,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.2881,
#   'price': 8995000.0,
#   'priceChange': -454000,
#   'priceForHDP': 8995000.0,
#   'priceReduction': '',
#   'rentZestimate': 28257,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1202 San Vicente Blvd',
#   'taxAssessedValue': 4584595.0,
#   'timeOnZillow': 13354751000,
#   'zipcode': '90402',
#   'zpid': 20477450},
#  {'bathrooms': 3.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6568e5c8d02ed024670101238ed99590-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.024708,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1865.0,
#   'longitude': -118.51018,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 1.5479,
#   'price': 2649000.0,
#   'priceForHDP': 2649000.0,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '515 Ocean Ave UNIT 502N',
#   'timeOnZillow': 2445326000,
#   'unit': 'Unit 502N',
#   'zipcode': '90402',
#   'zpid': 456559605},
#  {'bathrooms': 4.0,
#   'bedrooms': 6.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1758870000000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/990c03a3a764ff219370730760d0802b-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.03985,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 3103.0,
#   'longitude': -118.50098,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7527.168,
#   'price': 3995000.0,
#   'priceChange': 45000,
#   'priceForHDP': 3995000.0,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '212 16th St',
#   'taxAssessedValue': 286706.0,
#   'timeOnZillow': 4529628000,
#   'zipcode': '90402',
#   'zpid': 20477160},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1757055600000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/77e1c5f102c9809df8452a3552bb6117-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.025658,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 2000.0,
#   'longitude': -118.50825,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 10624.284,
#   'price': 5395000.0,
#   'priceChange': -100000,
#   'priceForHDP': 5395000.0,
#   'priceReduction': '$100,000 (Sep 5)',
#   'rentZestimate': 4919,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '227 Alta Ave',
#   'taxAssessedValue': 3163774.0,
#   'timeOnZillow': 2718797000,
#   'zestimate': 5296100,
#   'zipcode': '90402',
#   'zpid': 20486265},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1756364400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/521d94e157f6515eafa98cde3d7329a4-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.033016,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1803.0,
#   'longitude': -118.47912,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 5318.676,
#   'price': 1360000.0,
#   'priceChange': -30000,
#   'priceForHDP': 1360000.0,
#   'priceReduction': '$30,000 (Aug 28)',
#   'rentZestimate': 6633,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1240 24th St UNIT 3',
#   'taxAssessedValue': 1456414.0,
#   'timeOnZillow': 6951843000,
#   'unit': 'Unit 3',
#   'zestimate': 1354400,
#   'zipcode': '90404',
#   'zpid': 20474535},
#  {'bathrooms': 3.0,
#   'bedrooms': 6.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/7dedc9fefc17595800163e0a1cafdafb-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.016705,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 2751.0,
#   'longitude': -118.47945,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7497.0,
#   'price': 1950000.0,
#   'priceForHDP': 1950000.0,
#   'rentZestimate': 5535,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1836 Euclid St',
#   'taxAssessedValue': 1250567.0,
#   'timeOnZillow': 716210000,
#   'zestimate': 1930900,
#   'zipcode': '90404',
#   'zpid': 20480089},
#  {'bathrooms': 4.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5e1918eb31e27195c58ccfd65c4db5b5-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.030945,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1850.0,
#   'longitude': -118.4895,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7505.388,
#   'price': 1795000.0,
#   'priceForHDP': 1795000.0,
#   'rentZestimate': 7588,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1013 16th St UNIT 101',
#   'taxAssessedValue': 1210486.0,
#   'timeOnZillow': 6503423000,
#   'unit': 'Unit 101',
#   'zestimate': 1780000,
#   'zipcode': '90403',
#   'zpid': 20478100},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1759474800000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/511e1956dde315869615a5a7301828db-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.033455,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 2142.0,
#   'longitude': -118.49165,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7505.388,
#   'price': 2595000.0,
#   'priceChange': -100000,
#   'priceForHDP': 2595000.0,
#   'priceReduction': '$100,000 (Oct 3)',
#   'rentZestimate': 8328,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '838 17th St APT 105',
#   'taxAssessedValue': 2236860.0,
#   'timeOnZillow': 975846000,
#   'unit': 'Apt 105',
#   'zestimate': 2549100,
#   'zipcode': '90403',
#   'zpid': 51582400},
#  {'bathrooms': 4.0,
#   'bedrooms': 5.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/7350ec6dd16ce7ccea394a0c38ff3ec0-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.039165,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 3250.0,
#   'longitude': -118.50202,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7496.676,
#   'price': 5195000.0,
#   'priceForHDP': 5195000.0,
#   'rentZestimate': 17855,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '210 15th St',
#   'taxAssessedValue': 3865800.0,
#   'timeOnZillow': 970158000,
#   'zestimate': 5193300,
#   'zipcode': '90402',
#   'zpid': 20477206},
#  {'bathrooms': 4.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1b7dd78269c362b18695c71a49b83701-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.027794,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 2580.0,
#   'longitude': -118.49793,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7527.168,
#   'price': 2395000.0,
#   'priceForHDP': 2395000.0,
#   'rentZestimate': 7674,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '852 10th St APT 1',
#   'taxAssessedValue': 2043593.0,
#   'timeOnZillow': 307458000,
#   'unit': 'Apt 1',
#   'zestimate': 2377600,
#   'zipcode': '90403',
#   'zpid': 102961436},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3f69cc5669d280665b44daac091b0ff4-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.032608,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1588.0,
#   'longitude': -118.48961,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.34450000000000003,
#   'price': 1625000.0,
#   'priceForHDP': 1625000.0,
#   'rentZestimate': 6779,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '933 17th St UNIT 14',
#   'taxAssessedValue': 1485834.0,
#   'timeOnZillow': 5299736000,
#   'unit': 'Unit 14',
#   'zestimate': 1607500,
#   'zipcode': '90403',
#   'zpid': 20475069},
#  {'bathrooms': 8.0,
#   'bedrooms': 6.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f063974b84bbecb5541a4f073f0a6a9b-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.028465,
#   'listing_sub_type': {'is_newHome': True},
#   'livingArea': 7710.0,
#   'longitude': -118.50596,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.25358126721763086,
#   'newConstructionType': 'BUILDER_SPEC',
#   'price': 17818000.0,
#   'priceForHDP': 17818000.0,
#   'rentZestimate': 6712,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '528 Marguerita Ave',
#   'taxAssessedValue': 5618160.0,
#   'timeOnZillow': 1321010000,
#   'zestimate': 17165100,
#   'zipcode': '90402',
#   'zpid': 20486488},
#  {'bathrooms': 6.0,
#   'bedrooms': 5.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c914d925d44dd0e3630d4f9ed9719743-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.040005,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 4374.0,
#   'longitude': -118.48921,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7562.016,
#   'price': 6949000.0,
#   'priceForHDP': 6949000.0,
#   'rentZestimate': 22694,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '624 22nd St',
#   'taxAssessedValue': 4852502.0,
#   'timeOnZillow': 655165000,
#   'zipcode': '90402',
#   'zpid': 20476240},
#  {'bathrooms': 4.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1758524400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/297c6fe4158d91adab3e8fa438c2bec9-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.0276,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 4695.0,
#   'longitude': -118.50919,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 9801.0,
#   'price': 7475000.0,
#   'priceChange': -224000,
#   'priceForHDP': 7475000.0,
#   'priceReduction': '$224,000 (Sep 22)',
#   'rentZestimate': 7847,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '416 4th St',
#   'taxAssessedValue': 3684844.0,
#   'timeOnZillow': 7643044000,
#   'zestimate': 7482300,
#   'zipcode': '90402',
#   'zpid': 20486251},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/26787ea10e376ad86509d6999a1478cb-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.033756,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 935.0,
#   'longitude': -118.488304,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7984.548,
#   'price': 799000.0,
#   'priceForHDP': 799000.0,
#   'rentZestimate': 4278,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '934 19th St UNIT 5',
#   'taxAssessedValue': 382400.0,
#   'timeOnZillow': 1245610000,
#   'unit': 'Unit 5',
#   'zestimate': 800300,
#   'zipcode': '90403',
#   'zpid': 20475159},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/85b39c939bd56a98535421c5cce194c6-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02964,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1213.0,
#   'longitude': -118.49457,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.5171,
#   'price': 1425000.0,
#   'priceForHDP': 1425000.0,
#   'rentZestimate': 5194,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '900 Euclid St APT 404',
#   'taxAssessedValue': 1259184.0,
#   'timeOnZillow': 285514000,
#   'unit': 'Apt 404',
#   'zestimate': 1411600,
#   'zipcode': '90403',
#   'zpid': 20478617},
#  {'bathrooms': 7.0,
#   'bedrooms': 6.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f962f4612e338707fa65b3e24268de82-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.034992,
#   'listing_sub_type': {'is_newHome': True},
#   'livingArea': 5018.0,
#   'longitude': -118.49976,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7501.032,
#   'newConstructionType': 'BUILDER_SPEC',
#   'price': 7995000.0,
#   'priceForHDP': 7995000.0,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '443 Euclid St',
#   'taxAssessedValue': 3431044.0,
#   'timeOnZillow': 10714229000,
#   'zipcode': '90402',
#   'zpid': 20477746},
#  {'bathrooms': 3.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/2bb2e280c1f34f50db3aa3999fed4b9d-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.031902,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1356.0,
#   'longitude': -118.47384,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7008.804,
#   'price': 1225000.0,
#   'priceForHDP': 1225000.0,
#   'rentZestimate': 5093,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1443 25th St APT 2',
#   'taxAssessedValue': 873000.0,
#   'timeOnZillow': 384908000,
#   'unit': 'Apt 2',
#   'zestimate': 1205500,
#   'zipcode': '90404',
#   'zpid': 20473885},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/adf94cc6b6dcbd2d8b8c9ce00f9a8e3a-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.01113,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 842.0,
#   'longitude': -118.4833,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.46759999999999996,
#   'price': 949000.0,
#   'priceForHDP': 949000.0,
#   'rentZestimate': 3884,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '643 Bay St',
#   'taxAssessedValue': 880801.0,
#   'timeOnZillow': 1773329000,
#   'zestimate': 956900,
#   'zipcode': '90405',
#   'zpid': 20484049},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5ddc945798f128072debd34fc913c26e-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.033894,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1228.0,
#   'longitude': -118.47613,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 1.7036,
#   'price': 1089000.0,
#   'priceForHDP': 1089000.0,
#   'rentZestimate': 5216,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '2508 Arizona Ave APT 3',
#   'taxAssessedValue': 376687.0,
#   'timeOnZillow': 1245015000,
#   'unit': 'Apt 3',
#   'zestimate': 1079700,
#   'zipcode': '90404',
#   'zpid': 20474614},
#  {'bathrooms': 38.0,
#   'bedrooms': 38.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1756796400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'MULTI_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f84ebebd6a1780799e12591ef535466f-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02093,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 30954.0,
#   'longitude': -118.50543,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.34460514233241507,
#   'price': 30622000.0,
#   'priceChange': -2000000,
#   'priceForHDP': 30622000.0,
#   'priceReduction': '$2,000,000 (Sep 2)',
#   'rentZestimate': 3027,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '901 Ocean Ave',
#   'timeOnZillow': 7973810000,
#   'zipcode': '90403',
#   'zpid': 2068792684},
#  {'bathrooms': 4.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/799da9e2c3ff8411dac74555bb0615f0-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.031742,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 2085.0,
#   'longitude': -118.494125,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.3446,
#   'price': 2699000.0,
#   'priceForHDP': 2699000.0,
#   'rentZestimate': 8255,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '831 14th St APT 2',
#   'taxAssessedValue': 2028780.0,
#   'timeOnZillow': 2788432000,
#   'unit': 'Apt 2',
#   'zestimate': 2650700,
#   'zipcode': '90403',
#   'zpid': 20478314},
#  {'bathrooms': 8.0,
#   'bedrooms': 7.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/bf15b12e5f0d5da1ed06d7da7fcdfe46-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.041023,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 8400.0,
#   'longitude': -118.49285,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 8938.512,
#   'price': 19995000.0,
#   'priceForHDP': 19995000.0,
#   'rentZestimate': 17770,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '439 21st St',
#   'taxAssessedValue': 4284000.0,
#   'timeOnZillow': 11870599000,
#   'zestimate': 19287800,
#   'zipcode': '90402',
#   'zpid': 20476410},
#  {'bathrooms': 2.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/dd91f2355f4064ce8464d0eab79461e2-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.03284,
#   'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#   'livingArea': 1920.0,
#   'longitude': -118.49551,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7527.168,
#   'openHouse': 'Tue. 11am-2pm',
#   'open_house_info': {'open_house_showing': [{'open_house_end': 1759870800000,
#      'open_house_start': 1759860000000},
#     {'open_house_end': 1760313600000, 'open_house_start': 1760302800000}]},
#   'price': 3999000.0,
#   'priceForHDP': 3999000.0,
#   'rentZestimate': 5446,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '723 14th St',
#   'taxAssessedValue': 1456021.0,
#   'timeOnZillow': 2809863000,
#   'zestimate': 2932100,
#   'zipcode': '90402',
#   'zpid': 20477297},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1759129200000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/2a09adcdd68b48879861bf8c263f5b20-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.03607,
#   'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#   'livingArea': 1019.0,
#   'longitude': -118.48751,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 2988.216,
#   'openHouse': '10/16 10am-12pm',
#   'open_house_info': {'open_house_showing': [{'open_house_end': 1760641200000,
#      'open_house_start': 1760634000000}]},
#   'price': 2149999.0,
#   'priceChange': -50000,
#   'priceForHDP': 2149999.0,
#   'priceReduction': '$50,000 (Sep 29)',
#   'rentZestimate': 6534,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '2021 Idaho Ave',
#   'taxAssessedValue': 1893527.0,
#   'timeOnZillow': 2982424000,
#   'zestimate': 2130400,
#   'zipcode': '90403',
#   'zpid': 20474861},
#  {'bathrooms': 3.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/a32dadfc7b19df28b1c2b23cf4c7a23d-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02341,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1601.0,
#   'longitude': -118.50571,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7487.964,
#   'price': 1585000.0,
#   'priceForHDP': 1585000.0,
#   'rentZestimate': 7589,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '802 3rd St APT B',
#   'taxAssessedValue': 476496.0,
#   'timeOnZillow': 984628000,
#   'unit': 'Apt B',
#   'zestimate': 1582000,
#   'zipcode': '90403',
#   'zpid': 20485537},
#  {'bathrooms': 2.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1757401200000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/9c6fbb26017d30d4c9464ca66fe1c12f-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.034058,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1240.0,
#   'longitude': -118.48344,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 6351.048,
#   'price': 2650000.0,
#   'priceChange': -40000,
#   'priceForHDP': 2650000.0,
#   'priceReduction': '$40,000 (Sep 9)',
#   'rentZestimate': 7391,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1060 22nd St',
#   'taxAssessedValue': 756793.0,
#   'timeOnZillow': 6359397000,
#   'zestimate': 2623200,
#   'zipcode': '90403',
#   'zpid': 20475571},
#  {'bathrooms': 1.0,
#   'bedrooms': 2.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/96c92b05844a2faecb70765946f55d28-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.01245,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 785.0,
#   'longitude': -118.48446,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7501.032,
#   'price': 795000.0,
#   'priceForHDP': 795000.0,
#   'rentZestimate': 3410,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1835 7th St APT D',
#   'taxAssessedValue': 842723.0,
#   'timeOnZillow': 1075774000,
#   'unit': 'Apt D',
#   'zestimate': 791300,
#   'zipcode': '90401',
#   'zpid': 20484693},
#  {'bathrooms': 5.0,
#   'bedrooms': 4.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1752908400000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'SINGLE_FAMILY',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/bc7b9cf2f39ee122c91d24b99f95538b-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.033585,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 5228.0,
#   'longitude': -118.50931,
#   'lotAreaUnit': 'acres',
#   'lotAreaValue': 0.3438,
#   'price': 6750000.0,
#   'priceChange': -449000,
#   'priceForHDP': 6750000.0,
#   'priceReduction': '$449,000 (Jul 19)',
#   'rentZestimate': 6125,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '562 Stassi Ln',
#   'taxAssessedValue': 4987677.0,
#   'timeOnZillow': 18268525000,
#   'zestimate': 6939000,
#   'zipcode': '90402',
#   'zpid': 20539643},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'datePriceChanged': 1759474800000,
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'TOWNHOUSE',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/0e18d02c859abd1efb70a92a16cdada3-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.02262,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1963.0,
#   'longitude': -118.50478,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7501.032,
#   'price': 2699000.0,
#   'priceChange': -151000,
#   'priceForHDP': 2699000.0,
#   'priceReduction': '$151,000 (Oct 3)',
#   'rentZestimate': 7539,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '844 3rd St #5',
#   'taxAssessedValue': 2192756.0,
#   'timeOnZillow': 3120865000,
#   'unit': '# 5',
#   'zestimate': 2649300,
#   'zipcode': '90403',
#   'zpid': 55198014},
#  {'bathrooms': 3.0,
#   'bedrooms': 3.0,
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'currency': 'USD',
#   'daysOnZillow': -1,
#   'homeStatus': 'FOR_SALE',
#   'homeStatusForHDP': 'FOR_SALE',
#   'homeType': 'CONDO',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/69c1e7b08aaee035f696eb112dfdb1f6-p_e.jpg',
#   'isFeatured': False,
#   'isNonOwnerOccupied': True,
#   'isPreforeclosureAuction': False,
#   'isPremierBuilder': False,
#   'isShowcaseListing': False,
#   'isUnmappable': False,
#   'isZillowOwned': False,
#   'latitude': 34.01978,
#   'listing_sub_type': {'is_FSBA': True},
#   'livingArea': 1850.0,
#   'longitude': -118.50334,
#   'lotAreaUnit': 'sqft',
#   'lotAreaValue': 7514.1,
#   'price': 2694000.0,
#   'priceForHDP': 2694000.0,
#   'rentZestimate': 7813,
#   'shouldHighlight': False,
#   'state': 'CA',
#   'streetAddress': '1012 2nd St APT 1',
#   'timeOnZillow': 2789005000,
#   'unit': 'Apt 1',
#   'zestimate': 2678600,
#   'zipcode': '90403',
#   'zpid': 2098895547}]

# %%
a=pd.json_normalize(data['results'])

# %%
a
# Out:
#     bathrooms  bedrooms          city country currency  daysOnZillow  \
# 0         2.0       2.0  Santa Monica     USA      USD            -1
# 1         4.0       3.0  Santa Monica     USA      USD            -1
# 2         3.0       2.0  Santa Monica     USA      USD            -1
# 3        15.0      11.0  Santa Monica     USA      USD            -1
# 4         1.0       1.0  Santa Monica     USA      USD            -1
# 5         1.0       1.0  Santa Monica     USA      USD            -1
# 6         6.0       4.0  Santa Monica     USA      USD            -1
# 7         2.0       2.0  Santa Monica     USA      USD            -1
# 8         1.0       1.0  Santa Monica     USA      USD            -1
# 9         2.0       2.0  Santa Monica     USA      USD            -1
# 10        6.0       6.0  Santa Monica     USA      USD            -1
# 11        3.0       2.0  Santa Monica     USA      USD            -1
# 12        4.0       6.0  Santa Monica     USA      USD            -1
# 13        2.0       2.0  Santa Monica     USA      USD            -1
# 14        3.0       3.0  Santa Monica     USA      USD            -1
# 15        3.0       6.0  Santa Monica     USA      USD            -1
# 16        4.0       3.0  Santa Monica     USA      USD            -1
# 17        3.0       3.0  Santa Monica     USA      USD            -1
# 18        4.0       5.0  Santa Monica     USA      USD            -1
# 19        4.0       3.0  Santa Monica     USA      USD            -1
# 20        3.0       3.0  Santa Monica     USA      USD            -1
# 21        8.0       6.0  Santa Monica     USA      USD            -1
# 22        6.0       5.0  Santa Monica     USA      USD            -1
# 23        4.0       3.0  Santa Monica     USA      USD            -1
# 24        2.0       2.0  Santa Monica     USA      USD            -1
# 25        2.0       2.0  Santa Monica     USA      USD            -1
# 26        7.0       6.0  Santa Monica     USA      USD            -1
# 27        3.0       2.0  Santa Monica     USA      USD            -1
# 28        2.0       2.0  Santa Monica     USA      USD            -1
# 29        3.0       3.0  Santa Monica     USA      USD            -1
# 30       38.0      38.0  Santa Monica     USA      USD            -1
# 31        4.0       3.0  Santa Monica     USA      USD            -1
# 32        8.0       7.0  Santa Monica     USA      USD            -1
# 33        2.0       3.0  Santa Monica     USA      USD            -1
# 34        2.0       2.0  Santa Monica     USA      USD            -1
# 35        3.0       2.0  Santa Monica     USA      USD            -1
# 36        2.0       2.0  Santa Monica     USA      USD            -1
# 37        1.0       2.0  Santa Monica     USA      USD            -1
# 38        5.0       4.0  Santa Monica     USA      USD            -1
# 39        3.0       3.0  Santa Monica     USA      USD            -1
# 40        3.0       3.0  Santa Monica     USA      USD            -1
#
#    homeStatus homeStatusForHDP       homeType  \
# 0    FOR_SALE         FOR_SALE          CONDO
# 1    FOR_SALE         FOR_SALE   MULTI_FAMILY
# 2    FOR_SALE         FOR_SALE          CONDO
# 3    FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 4    FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 5    FOR_SALE         FOR_SALE          CONDO
# 6    FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 7    FOR_SALE         FOR_SALE          CONDO
# 8    FOR_SALE         FOR_SALE          CONDO
# 9    FOR_SALE         FOR_SALE          CONDO
# 10   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 11   FOR_SALE         FOR_SALE          CONDO
# 12   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 13   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 14   FOR_SALE         FOR_SALE      TOWNHOUSE
# 15   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 16   FOR_SALE         FOR_SALE      TOWNHOUSE
# 17   FOR_SALE         FOR_SALE      TOWNHOUSE
# 18   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 19   FOR_SALE         FOR_SALE          CONDO
# 20   FOR_SALE         FOR_SALE      TOWNHOUSE
# 21   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 22   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 23   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 24   FOR_SALE         FOR_SALE          CONDO
# 25   FOR_SALE         FOR_SALE          CONDO
# 26   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 27   FOR_SALE         FOR_SALE      TOWNHOUSE
# 28   FOR_SALE         FOR_SALE          CONDO
# 29   FOR_SALE         FOR_SALE      TOWNHOUSE
# 30   FOR_SALE         FOR_SALE   MULTI_FAMILY
# 31   FOR_SALE         FOR_SALE      TOWNHOUSE
# 32   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 33   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 34   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 35   FOR_SALE         FOR_SALE      TOWNHOUSE
# 36   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 37   FOR_SALE         FOR_SALE          CONDO
# 38   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 39   FOR_SALE         FOR_SALE      TOWNHOUSE
# 40   FOR_SALE         FOR_SALE          CONDO
#
#                                                imgSrc  ...  zipcode  \
# 0   https://photos.zillowstatic.com/fp/9ac0d58bd94...  ...    90403
# 1   https://photos.zillowstatic.com/fp/c6843720f4b...  ...    90403
# 2   https://photos.zillowstatic.com/fp/cfc9a51e88f...  ...    90404
# 3   https://photos.zillowstatic.com/fp/fa16ff881b0...  ...    90403
# 4   https://photos.zillowstatic.com/fp/0ab3516293c...  ...    90403
# 5   https://photos.zillowstatic.com/fp/379ba2c7ab0...  ...    90403
# 6   https://photos.zillowstatic.com/fp/3cbebb772f8...  ...    90403
# 7   https://photos.zillowstatic.com/fp/ca026d0c07e...  ...    90403
# 8   https://photos.zillowstatic.com/fp/08b9533ab23...  ...    90404
# 9   https://photos.zillowstatic.com/fp/3b06e5e0488...  ...    90403
# 10  https://photos.zillowstatic.com/fp/8221c459d72...  ...    90402
# 11  https://photos.zillowstatic.com/fp/6568e5c8d02...  ...    90402
# 12  https://photos.zillowstatic.com/fp/990c03a3a76...  ...    90402
# 13  https://photos.zillowstatic.com/fp/77e1c5f102c...  ...    90402
# 14  https://photos.zillowstatic.com/fp/521d94e157f...  ...    90404
# 15  https://photos.zillowstatic.com/fp/7dedc9fefc1...  ...    90404
# 16  https://photos.zillowstatic.com/fp/5e1918eb31e...  ...    90403
# 17  https://photos.zillowstatic.com/fp/511e1956dde...  ...    90403
# 18  https://photos.zillowstatic.com/fp/7350ec6dd16...  ...    90402
# 19  https://photos.zillowstatic.com/fp/1b7dd78269c...  ...    90403
# 20  https://photos.zillowstatic.com/fp/3f69cc5669d...  ...    90403
# 21  https://photos.zillowstatic.com/fp/f063974b84b...  ...    90402
# 22  https://photos.zillowstatic.com/fp/c914d925d44...  ...    90402
# 23  https://photos.zillowstatic.com/fp/297c6fe4158...  ...    90402
# 24  https://photos.zillowstatic.com/fp/26787ea10e3...  ...    90403
# 25  https://photos.zillowstatic.com/fp/85b39c939bd...  ...    90403
# 26  https://photos.zillowstatic.com/fp/f962f4612e3...  ...    90402
# 27  https://photos.zillowstatic.com/fp/2bb2e280c1f...  ...    90404
# 28  https://photos.zillowstatic.com/fp/adf94cc6b6d...  ...    90405
# 29  https://photos.zillowstatic.com/fp/5ddc945798f...  ...    90404
# 30  https://photos.zillowstatic.com/fp/f84ebebd6a1...  ...    90403
# 31  https://photos.zillowstatic.com/fp/799da9e2c3f...  ...    90403
# 32  https://photos.zillowstatic.com/fp/bf15b12e5f0...  ...    90402
# 33  https://photos.zillowstatic.com/fp/dd91f2355f4...  ...    90402
# 34  https://photos.zillowstatic.com/fp/2a09adcdd68...  ...    90403
# 35  https://photos.zillowstatic.com/fp/a32dadfc7b1...  ...    90403
# 36  https://photos.zillowstatic.com/fp/9c6fbb26017...  ...    90403
# 37  https://photos.zillowstatic.com/fp/96c92b05844...  ...    90401
# 38  https://photos.zillowstatic.com/fp/bc7b9cf2f39...  ...    90402
# 39  https://photos.zillowstatic.com/fp/0e18d02c859...  ...    90403
# 40  https://photos.zillowstatic.com/fp/69c1e7b08aa...  ...    90403
#
#           zpid  listing_sub_type.is_FSBA  listing_sub_type.is_openHouse  \
# 0     20484992                      True                           True
# 1    455351929                      True                            NaN
# 2     20479916                      True                            NaN
# 3    456957893                      True                            NaN
# 4     20478685                      True                            NaN
# 5     20485330                      True                            NaN
# 6     20485846                      True                            NaN
# 7     20484960                      True                            NaN
# 8     92426247                      True                            NaN
# 9     20485470                      True                            NaN
# 10    20477450                      True                            NaN
# 11   456559605                      True                            NaN
# 12    20477160                      True                            NaN
# 13    20486265                      True                            NaN
# 14    20474535                      True                            NaN
# 15    20480089                      True                            NaN
# 16    20478100                      True                            NaN
# 17    51582400                      True                            NaN
# 18    20477206                      True                            NaN
# 19   102961436                      True                            NaN
# 20    20475069                      True                            NaN
# 21    20486488                       NaN                            NaN
# 22    20476240                      True                            NaN
# 23    20486251                      True                            NaN
# 24    20475159                      True                            NaN
# 25    20478617                      True                            NaN
# 26    20477746                       NaN                            NaN
# 27    20473885                      True                            NaN
# 28    20484049                      True                            NaN
# 29    20474614                      True                            NaN
# 30  2068792684                      True                            NaN
# 31    20478314                      True                            NaN
# 32    20476410                      True                            NaN
# 33    20477297                      True                           True
# 34    20474861                      True                           True
# 35    20485537                      True                            NaN
# 36    20475571                      True                            NaN
# 37    20484693                      True                            NaN
# 38    20539643                      True                            NaN
# 39    55198014                      True                            NaN
# 40  2098895547                      True                            NaN
#
#                    open_house_info.open_house_showing  datePriceChanged  \
# 0   [{'open_house_end': 1760223600000, 'open_house...               NaN
# 1                                                 NaN      1.759216e+12
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN      1.755328e+12
# 5                                                 NaN      1.756364e+12
# 6                                                 NaN               NaN
# 7                                                 NaN      1.756883e+12
# 8                                                 NaN      1.750316e+12
# 9                                                 NaN               NaN
# 10                                                NaN      1.750230e+12
# 11                                                NaN               NaN
# 12                                                NaN      1.758870e+12
# 13                                                NaN      1.757056e+12
# 14                                                NaN      1.756364e+12
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN      1.759475e+12
# 18                                                NaN               NaN
# 19                                                NaN               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN      1.758524e+12
# 24                                                NaN               NaN
# 25                                                NaN               NaN
# 26                                                NaN               NaN
# 27                                                NaN               NaN
# 28                                                NaN               NaN
# 29                                                NaN               NaN
# 30                                                NaN      1.756796e+12
# 31                                                NaN               NaN
# 32                                                NaN               NaN
# 33  [{'open_house_end': 1759870800000, 'open_house...               NaN
# 34  [{'open_house_end': 1760641200000, 'open_house...      1.759129e+12
# 35                                                NaN               NaN
# 36                                                NaN      1.757401e+12
# 37                                                NaN               NaN
# 38                                                NaN      1.752908e+12
# 39                                                NaN      1.759475e+12
# 40                                                NaN               NaN
#
#     priceChange      priceReduction  newConstructionType  \
# 0           NaN                 NaN                  NaN
# 1     -150000.0   $150,000 (Sep 30)                  NaN
# 2           NaN                 NaN                  NaN
# 3           NaN                 NaN                  NaN
# 4     -101000.0   $101,000 (Aug 16)                  NaN
# 5      -40800.0    $40,800 (Aug 28)                  NaN
# 6           NaN                 NaN                  NaN
# 7      -30000.0     $30,000 (Sep 3)                  NaN
# 8      -51000.0                                      NaN
# 9           NaN                 NaN                  NaN
# 10    -454000.0                                      NaN
# 11          NaN                 NaN                  NaN
# 12      45000.0                 NaN                  NaN
# 13    -100000.0    $100,000 (Sep 5)                  NaN
# 14     -30000.0    $30,000 (Aug 28)                  NaN
# 15          NaN                 NaN                  NaN
# 16          NaN                 NaN                  NaN
# 17    -100000.0    $100,000 (Oct 3)                  NaN
# 18          NaN                 NaN                  NaN
# 19          NaN                 NaN                  NaN
# 20          NaN                 NaN                  NaN
# 21          NaN                 NaN         BUILDER_SPEC
# 22          NaN                 NaN                  NaN
# 23    -224000.0   $224,000 (Sep 22)                  NaN
# 24          NaN                 NaN                  NaN
# 25          NaN                 NaN                  NaN
# 26          NaN                 NaN         BUILDER_SPEC
# 27          NaN                 NaN                  NaN
# 28          NaN                 NaN                  NaN
# 29          NaN                 NaN                  NaN
# 30   -2000000.0  $2,000,000 (Sep 2)                  NaN
# 31          NaN                 NaN                  NaN
# 32          NaN                 NaN                  NaN
# 33          NaN                 NaN                  NaN
# 34     -50000.0    $50,000 (Sep 29)                  NaN
# 35          NaN                 NaN                  NaN
# 36     -40000.0     $40,000 (Sep 9)                  NaN
# 37          NaN                 NaN                  NaN
# 38    -449000.0   $449,000 (Jul 19)                  NaN
# 39    -151000.0    $151,000 (Oct 3)                  NaN
# 40          NaN                 NaN                  NaN
#
#     listing_sub_type.is_newHome
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                         True
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                         True
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
#
# [41 rows x 43 columns]

# %%
a.to_csv('home.csv')

# %%
a.head()
# Out:
#    bathrooms  bedrooms          city country currency  daysOnZillow  \
# 0        2.0       2.0  Santa Monica     USA      USD            -1
# 1        4.0       3.0  Santa Monica     USA      USD            -1
# 2        3.0       2.0  Santa Monica     USA      USD            -1
# 3       15.0      11.0  Santa Monica     USA      USD            -1
# 4        1.0       1.0  Santa Monica     USA      USD            -1
#
#   homeStatus homeStatusForHDP       homeType  \
# 0   FOR_SALE         FOR_SALE          CONDO
# 1   FOR_SALE         FOR_SALE   MULTI_FAMILY
# 2   FOR_SALE         FOR_SALE          CONDO
# 3   FOR_SALE         FOR_SALE  SINGLE_FAMILY
# 4   FOR_SALE         FOR_SALE  SINGLE_FAMILY
#
#                                               imgSrc  ...  zipcode       zpid  \
# 0  https://photos.zillowstatic.com/fp/9ac0d58bd94...  ...    90403   20484992
# 1  https://photos.zillowstatic.com/fp/c6843720f4b...  ...    90403  455351929
# 2  https://photos.zillowstatic.com/fp/cfc9a51e88f...  ...    90404   20479916
# 3  https://photos.zillowstatic.com/fp/fa16ff881b0...  ...    90403  456957893
# 4  https://photos.zillowstatic.com/fp/0ab3516293c...  ...    90403   20478685
#
#    listing_sub_type.is_FSBA  listing_sub_type.is_openHouse  \
# 0                      True                           True
# 1                      True                            NaN
# 2                      True                            NaN
# 3                      True                            NaN
# 4                      True                            NaN
#
#                   open_house_info.open_house_showing  datePriceChanged  \
# 0  [{'open_house_end': 1760223600000, 'open_house...               NaN
# 1                                                NaN      1.759216e+12
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN      1.755328e+12
#
#    priceChange     priceReduction  newConstructionType  \
# 0          NaN                NaN                  NaN
# 1    -150000.0  $150,000 (Sep 30)                  NaN
# 2          NaN                NaN                  NaN
# 3          NaN                NaN                  NaN
# 4    -101000.0  $101,000 (Aug 16)                  NaN
#
#    listing_sub_type.is_newHome
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 43 columns]
